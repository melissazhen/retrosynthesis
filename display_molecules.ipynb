# %%
import pandas as pd
from rdkit import Chem
import rdkit.Chem.AllChem as AllChem
data=pd.read_csv("energetic materials_smiles.csv",encoding="gbk")
Product_mols = []
m=0
for i in data['SMILES']:
    Product_mol = Chem.MolFromSmiles(str(i))
    display(Product_mol)
    m+=1
print(m)
# Out:
# [23:17:56] Explicit valence for atom # 4 C, 5, is greater than permitted
# None
# [23:17:56] SMILES Parse Error: syntax error while parsing: nan
# [23:17:56] SMILES Parse Error: Failed parsing SMILES 'nan' for input: 'nan'
# None
# [23:17:56] SMILES Parse Error: syntax error while parsing: nan
# [23:17:56] SMILES Parse Error: Failed parsing SMILES 'nan' for input: 'nan'
# None
# [23:17:56] SMILES Parse Error: syntax error while parsing: nan
# [23:17:56] SMILES Parse Error: Failed parsing SMILES 'nan' for input: 'nan'
# None
# [23:17:56] SMILES Parse Error: syntax error while parsing: nan
# [23:17:56] SMILES Parse Error: Failed parsing SMILES 'nan' for input: 'nan'
# None
# [23:17:56] SMILES Parse Error: syntax error while parsing: nan
# [23:17:56] SMILES Parse Error: Failed parsing SMILES 'nan' for input: 'nan'
# None
# [23:17:56] SMILES Parse Error: syntax error while parsing: nan
# [23:17:56] SMILES Parse Error: Failed parsing SMILES 'nan' for input: 'nan'
# None
# 116
